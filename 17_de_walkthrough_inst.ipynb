# %% [markdown]
# ## **17. 데이터 프로젝트 예제: Energy Star Score Prediction**

# %% [markdown]
# ### **1. 데이터 로딩 및 형변환**

# %%
from pathlib import Path

import pandas as pd
import numpy as np

# 데이터프레임 로딩
candidates = [
    Path('ny_energy_2016.csv'),
    Path.cwd() / 'ny_energy_2016.csv',
]

if Path.cwd().name != '':
    candidates.extend(Path.cwd().glob('**/ny_energy_2016.csv'))
    if Path.cwd().parent.exists():
        candidates.extend(Path.cwd().parent.glob('**/ny_energy_2016.csv'))

for path in candidates:
    if path.exists():
        data_path = path
        break
else:
    raise FileNotFoundError('ny_energy_2016.csv file not found.')

print(data_path)
df = pd.read_csv(data_path)
df.head()
# Out:
# ny_energy_2016.csv
#    Order  Property Id                                 Property Name  \
# 0      1        13286                                       201/205
# 1      2        28400                    NYP Columbia (West Campus)
# 2      3      4778226                                 MSCHoNY North
# 3      4      4778267  Herbert Irving Pavilion & Millstein Hospital
# 4      5      4778288                               Neuro Institute
#
#   Parent Property Id        Parent Property Name BBL - 10 digits  \
# 0              13286                     201/205      1013160001
# 1              28400  NYP Columbia (West Campus)      1021380040
# 2              28400  NYP Columbia (West Campus)      1021380030
# 3              28400  NYP Columbia (West Campus)      1021390001
# 4              28400  NYP Columbia (West Campus)      1021390085
#
#   NYC Borough, Block and Lot (BBL) self-reported  \
# 0                                     1013160001
# 1                                   1-02138-0040
# 2                                   1-02138-0030
# 3                                   1-02139-0001
# 4                                   1-02139-0085
#
#             NYC Building Identification Number (BIN)  \
# 0                                            1037549
# 1  1084198; 1084387;1084385; 1084386; 1084388; 10...
# 2                                            1063380
# 3                                   1087281; 1076746
# 4                                            1063403
#
#   Address 1 (self-reported)                Address 2  ...  \
# 0  201/205  East  42nd  st.            Not Available  ...
# 1          622 168th Street            Not Available  ...
# 2             3975 Broadway            Not Available  ...
# 3   161 Fort Washington Ave  177 Fort Washington Ave  ...
# 4     710 West 168th Street            Not Available  ...
#
#   Source EUI (kBtu/ft²)            Release Date Water Required?  \
# 0                 619.4  05/01/2017 05:32:03 PM              No
# 1                 404.3  04/27/2017 11:23:27 AM              No
# 2         Not Available  04/27/2017 11:23:27 AM              No
# 3         Not Available  04/27/2017 11:23:27 AM              No
# 4         Not Available  04/27/2017 11:23:27 AM              No
#
#   DOF Benchmarking Submission Status   Latitude  Longitude Community Board  \
# 0                      In Compliance  40.750791 -73.973963             6.0
# 1                      In Compliance  40.841402 -73.942568            12.0
# 2                      In Compliance  40.840427 -73.940249            12.0
# 3                      In Compliance  40.840746 -73.942854            12.0
# 4                      In Compliance  40.841559 -73.942528            12.0
#
#   Council District Census Tract  \
# 0              4.0         88.0
# 1             10.0        251.0
# 2             10.0        251.0
# 3             10.0        255.0
# 4             10.0        255.0
#
#                                                  NTA
# 0  Turtle Bay-East Midtown                       ...
# 1  Washington Heights South                      ...
# 2  Washington Heights South                      ...
# 3  Washington Heights South                      ...
# 4  Washington Heights South                      ...
#
# [5 rows x 60 columns]

# %%
# 데이터프레임 요약 정보
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 11746 entries, 0 to 11745
# Data columns (total 60 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   Order                                                       11746 non-null  int64
#  1   Property Id                                                 11746 non-null  int64
#  2   Property Name                                               11746 non-null  str
#  3   Parent Property Id                                          11746 non-null  str
#  4   Parent Property Name                                        11746 non-null  str
#  5   BBL - 10 digits                                             11735 non-null  str
#  6   NYC Borough, Block and Lot (BBL) self-reported              11746 non-null  str
#  7   NYC Building Identification Number (BIN)                    11746 non-null  str
#  8   Address 1 (self-reported)                                   11746 non-null  str
#  9   Address 2                                                   11746 non-null  str
#  10  Postal Code                                                 11746 non-null  str
#  11  Street Number                                               11622 non-null  str
#  12  Street Name                                                 11624 non-null  str
#  13  Borough                                                     11628 non-null  str
#  14  DOF Gross Floor Area                                        11628 non-null  float64
#  15  Primary Property Type - Self Selected                       11746 non-null  str
#  16  List of All Property Use Types at Property                  11746 non-null  str
#  17  Largest Property Use Type                                   11746 non-null  str
#  18  Largest Property Use Type - Gross Floor Area (ft²)          11746 non-null  str
#  19  2nd Largest Property Use Type                               11746 non-null  str
#  20  2nd Largest Property Use - Gross Floor Area (ft²)           11746 non-null  str
#  21  3rd Largest Property Use Type                               11746 non-null  str
#  22  3rd Largest Property Use Type - Gross Floor Area (ft²)      11746 non-null  str
#  23  Year Built                                                  11746 non-null  int64
#  24  Number of Buildings - Self-reported                         11746 non-null  int64
#  25  Occupancy                                                   11746 non-null  int64
#  26  Metered Areas (Energy)                                      11746 non-null  str
#  27  Metered Areas  (Water)                                      11746 non-null  str
#  28  ENERGY STAR Score                                           11746 non-null  str
#  29  Site EUI (kBtu/ft²)                                         11746 non-null  str
#  30  Weather Normalized Site EUI (kBtu/ft²)                      11746 non-null  str
#  31  Weather Normalized Site Electricity Intensity (kWh/ft²)     11746 non-null  str
#  32  Weather Normalized Site Natural Gas Intensity (therms/ft²)  11746 non-null  str
#  33  Weather Normalized Source EUI (kBtu/ft²)                    11746 non-null  str
#  34  Fuel Oil #1 Use (kBtu)                                      11746 non-null  str
#  35  Fuel Oil #2 Use (kBtu)                                      11746 non-null  str
#  36  Fuel Oil #4 Use (kBtu)                                      11746 non-null  str
#  37  Fuel Oil #5 & 6 Use (kBtu)                                  11746 non-null  str
#  38  Diesel #2 Use (kBtu)                                        11746 non-null  str
#  39  District Steam Use (kBtu)                                   11746 non-null  str
#  40  Natural Gas Use (kBtu)                                      11746 non-null  str
#  41  Weather Normalized Site Natural Gas Use (therms)            11746 non-null  str
#  42  Electricity Use - Grid Purchase (kBtu)                      11746 non-null  str
#  43  Weather Normalized Site Electricity (kWh)                   11746 non-null  str
#  44  Total GHG Emissions (Metric Tons CO2e)                      11746 non-null  str
#  45  Direct GHG Emissions (Metric Tons CO2e)                     11746 non-null  str
#  46  Indirect GHG Emissions (Metric Tons CO2e)                   11746 non-null  str
#  47  Property GFA - Self-Reported (ft²)                          11746 non-null  int64
#  48  Water Use (All Water Sources) (kgal)                        11746 non-null  str
#  49  Water Intensity (All Water Sources) (gal/ft²)               11746 non-null  str
#  50  Source EUI (kBtu/ft²)                                       11746 non-null  str
#  51  Release Date                                                11746 non-null  str
#  52  Water Required?                                             11628 non-null  str
#  53  DOF Benchmarking Submission Status                          11716 non-null  str
#  54  Latitude                                                    9483 non-null   float64
#  55  Longitude                                                   9483 non-null   float64
#  56  Community Board                                             9483 non-null   float64
#  57  Council District                                            9483 non-null   float64
#  58  Census Tract                                                9483 non-null   float64
#  59  NTA                                                         9483 non-null   str
# dtypes: float64(6), int64(6), str(48)
# memory usage: 5.4 MB

# %% [markdown]
# **[데이터 정리]** 데이터셋에서 결측값들은 "**Not Available**"라는 텍스트로 기록됨 ${\rightarrow}$ pandas에서 인식 가능한 결측 값(```np.nan```)으로 변경

# %%
# "Not Available" 값 포함 여부 출력
df[df == "Not Available"].any()
# Out:
# Order                                                         False
# Property Id                                                   False
# Property Name                                                 False
# Parent Property Id                                            False
# Parent Property Name                                          False
# BBL - 10 digits                                               False
# NYC Borough, Block and Lot (BBL) self-reported                 True
# NYC Building Identification Number (BIN)                       True
# Address 1 (self-reported)                                     False
# Address 2                                                      True
# Postal Code                                                   False
# Street Number                                                 False
# Street Name                                                   False
# Borough                                                       False
# DOF Gross Floor Area                                          False
# Primary Property Type - Self Selected                         False
# List of All Property Use Types at Property                    False
# Largest Property Use Type                                      True
# Largest Property Use Type - Gross Floor Area (ft²)             True
# 2nd Largest Property Use Type                                  True
# 2nd Largest Property Use - Gross Floor Area (ft²)              True
# 3rd Largest Property Use Type                                  True
# 3rd Largest Property Use Type - Gross Floor Area (ft²)         True
# Year Built                                                    False
# Number of Buildings - Self-reported                           False
# Occupancy                                                     False
# Metered Areas (Energy)                                         True
# Metered Areas  (Water)                                         True
# ENERGY STAR Score                                              True
# Site EUI (kBtu/ft²)                                            True
# Weather Normalized Site EUI (kBtu/ft²)                         True
# Weather Normalized Site Electricity Intensity (kWh/ft²)        True
# Weather Normalized Site Natural Gas Intensity (therms/ft²)     True
# Weather Normalized Source EUI (kBtu/ft²)                       True
# Fuel Oil #1 Use (kBtu)                                         True
# Fuel Oil #2 Use (kBtu)                                         True
# Fuel Oil #4 Use (kBtu)                                         True
# Fuel Oil #5 & 6 Use (kBtu)                                     True
# Diesel #2 Use (kBtu)                                           True
# District Steam Use (kBtu)                                      True
# Natural Gas Use (kBtu)                                         True
# Weather Normalized Site Natural Gas Use (therms)               True
# Electricity Use - Grid Purchase (kBtu)                         True
# Weather Normalized Site Electricity (kWh)                      True
# Total GHG Emissions (Metric Tons CO2e)                         True
# Direct GHG Emissions (Metric Tons CO2e)                        True
# Indirect GHG Emissions (Metric Tons CO2e)                      True
# Property GFA - Self-Reported (ft²)                            False
# Water Use (All Water Sources) (kgal)                           True
# Water Intensity (All Water Sources) (gal/ft²)                  True
# Source EUI (kBtu/ft²)                                          True
# Release Date                                                  False
# Water Required?                                               False
# DOF Benchmarking Submission Status                            False
# Latitude                                                      False
# Longitude                                                     False
# Community Board                                               False
# Council District                                              False
# Census Tract                                                  False
# NTA                                                           False
# dtype: bool

# %%
# "Not Available" 값을 np.nan으로 대체
df.replace({'Not Available': np.nan}, inplace=True) 
df[df == "Not Available"].any()
# Out:
# Order                                                         False
# Property Id                                                   False
# Property Name                                                 False
# Parent Property Id                                            False
# Parent Property Name                                          False
# BBL - 10 digits                                               False
# NYC Borough, Block and Lot (BBL) self-reported                False
# NYC Building Identification Number (BIN)                      False
# Address 1 (self-reported)                                     False
# Address 2                                                     False
# Postal Code                                                   False
# Street Number                                                 False
# Street Name                                                   False
# Borough                                                       False
# DOF Gross Floor Area                                          False
# Primary Property Type - Self Selected                         False
# List of All Property Use Types at Property                    False
# Largest Property Use Type                                     False
# Largest Property Use Type - Gross Floor Area (ft²)            False
# 2nd Largest Property Use Type                                 False
# 2nd Largest Property Use - Gross Floor Area (ft²)             False
# 3rd Largest Property Use Type                                 False
# 3rd Largest Property Use Type - Gross Floor Area (ft²)        False
# Year Built                                                    False
# Number of Buildings - Self-reported                           False
# Occupancy                                                     False
# Metered Areas (Energy)                                        False
# Metered Areas  (Water)                                        False
# ENERGY STAR Score                                             False
# Site EUI (kBtu/ft²)                                           False
# Weather Normalized Site EUI (kBtu/ft²)                        False
# Weather Normalized Site Electricity Intensity (kWh/ft²)       False
# Weather Normalized Site Natural Gas Intensity (therms/ft²)    False
# Weather Normalized Source EUI (kBtu/ft²)                      False
# Fuel Oil #1 Use (kBtu)                                        False
# Fuel Oil #2 Use (kBtu)                                        False
# Fuel Oil #4 Use (kBtu)                                        False
# Fuel Oil #5 & 6 Use (kBtu)                                    False
# Diesel #2 Use (kBtu)                                          False
# District Steam Use (kBtu)                                     False
# Natural Gas Use (kBtu)                                        False
# Weather Normalized Site Natural Gas Use (therms)              False
# Electricity Use - Grid Purchase (kBtu)                        False
# Weather Normalized Site Electricity (kWh)                     False
# Total GHG Emissions (Metric Tons CO2e)                        False
# Direct GHG Emissions (Metric Tons CO2e)                       False
# Indirect GHG Emissions (Metric Tons CO2e)                     False
# Property GFA - Self-Reported (ft²)                            False
# Water Use (All Water Sources) (kgal)                          False
# Water Intensity (All Water Sources) (gal/ft²)                 False
# Source EUI (kBtu/ft²)                                         False
# Release Date                                                  False
# Water Required?                                               False
# DOF Benchmarking Submission Status                            False
# Latitude                                                      False
# Longitude                                                     False
# Community Board                                               False
# Council District                                              False
# Census Tract                                                  False
# NTA                                                           False
# dtype: bool

# %% [markdown]
# **[데이터 형변환]** 수치형 변수들의 데이터 타입을 **float64**형으로 변경

# %%
for col in list(df.columns):
    # 변수명에 수치 단위가 포함된 변수만 선택
    if('ft²' in col or 
        'kBtu' in col or
        'Metric Tons CO2e' in col or
        'kWh' in col or
        'therms' in col or
        'gal' in col or
        'Score' in col):
            
            # 데이터 타입 변경
            df[col] = df[col].astype('float64')

df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 11746 entries, 0 to 11745
# Data columns (total 60 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   Order                                                       11746 non-null  int64
#  1   Property Id                                                 11746 non-null  int64
#  2   Property Name                                               11746 non-null  str
#  3   Parent Property Id                                          11746 non-null  str
#  4   Parent Property Name                                        11746 non-null  str
#  5   BBL - 10 digits                                             11735 non-null  str
#  6   NYC Borough, Block and Lot (BBL) self-reported              11735 non-null  str
#  7   NYC Building Identification Number (BIN)                    11584 non-null  str
#  8   Address 1 (self-reported)                                   11746 non-null  str
#  9   Address 2                                                   207 non-null    str
#  10  Postal Code                                                 11746 non-null  str
#  11  Street Number                                               11622 non-null  str
#  12  Street Name                                                 11624 non-null  str
#  13  Borough                                                     11628 non-null  str
#  14  DOF Gross Floor Area                                        11628 non-null  float64
#  15  Primary Property Type - Self Selected                       11746 non-null  str
#  16  List of All Property Use Types at Property                  11746 non-null  str
#  17  Largest Property Use Type                                   11744 non-null  str
#  18  Largest Property Use Type - Gross Floor Area (ft²)          11744 non-null  str
#  19  2nd Largest Property Use Type                               3741 non-null   str
#  20  2nd Largest Property Use - Gross Floor Area (ft²)           3741 non-null   str
#  21  3rd Largest Property Use Type                               1484 non-null   str
#  22  3rd Largest Property Use Type - Gross Floor Area (ft²)      1484 non-null   str
#  23  Year Built                                                  11746 non-null  int64
#  24  Number of Buildings - Self-reported                         11746 non-null  int64
#  25  Occupancy                                                   11746 non-null  int64
#  26  Metered Areas (Energy)                                      11689 non-null  str
#  27  Metered Areas  (Water)                                      7137 non-null   str
#  28  ENERGY STAR Score                                           9642 non-null   float64
#  29  Site EUI (kBtu/ft²)                                         11583 non-null  float64
#  30  Weather Normalized Site EUI (kBtu/ft²)                      10281 non-null  float64
#  31  Weather Normalized Site Electricity Intensity (kWh/ft²)     10959 non-null  float64
#  32  Weather Normalized Site Natural Gas Intensity (therms/ft²)  9783 non-null   float64
#  33  Weather Normalized Source EUI (kBtu/ft²)                    10281 non-null  float64
#  34  Fuel Oil #1 Use (kBtu)                                      9 non-null      float64
#  35  Fuel Oil #2 Use (kBtu)                                      2581 non-null   float64
#  36  Fuel Oil #4 Use (kBtu)                                      1321 non-null   float64
#  37  Fuel Oil #5 & 6 Use (kBtu)                                  594 non-null    float64
#  38  Diesel #2 Use (kBtu)                                        16 non-null     float64
#  39  District Steam Use (kBtu)                                   936 non-null    float64
#  40  Natural Gas Use (kBtu)                                      10304 non-null  float64
#  41  Weather Normalized Site Natural Gas Use (therms)            9784 non-null   float64
#  42  Electricity Use - Grid Purchase (kBtu)                      11502 non-null  float64
#  43  Weather Normalized Site Electricity (kWh)                   10960 non-null  float64
#  44  Total GHG Emissions (Metric Tons CO2e)                      11672 non-null  float64
#  45  Direct GHG Emissions (Metric Tons CO2e)                     11663 non-null  float64
#  46  Indirect GHG Emissions (Metric Tons CO2e)                   11681 non-null  float64
#  47  Property GFA - Self-Reported (ft²)                          11746 non-null  int64
#  48  Water Use (All Water Sources) (kgal)                        7762 non-null   float64
#  49  Water Intensity (All Water Sources) (gal/ft²)               7762 non-null   float64
#  50  Source EUI (kBtu/ft²)                                       11583 non-null  float64
#  51  Release Date                                                11746 non-null  str
#  52  Water Required?                                             11628 non-null  str
#  53  DOF Benchmarking Submission Status                          11716 non-null  str
#  54  Latitude                                                    9483 non-null   float64
#  55  Longitude                                                   9483 non-null   float64
#  56  Community Board                                             9483 non-null   float64
#  57  Council District                                            9483 non-null   float64
#  58  Census Tract                                                9483 non-null   float64
#  59  NTA                                                         9483 non-null   str
# dtypes: float64(28), int64(6), str(26)
# memory usage: 5.4 MB

# %% [markdown]
# **[데이터 클리닝]** 1차 결측치 처리 ${\rightarrow}$ 결측 비율 높은 변수 제거

# %%
# 변수별 결측치 개수
ser_miss_cnt = df.isnull().sum().sort_values(ascending = False)
ser_miss_cnt
# Out:
# Fuel Oil #1 Use (kBtu)                                        11737
# Diesel #2 Use (kBtu)                                          11730
# Address 2                                                     11539
# Fuel Oil #5 & 6 Use (kBtu)                                    11152
# District Steam Use (kBtu)                                     10810
# Fuel Oil #4 Use (kBtu)                                        10425
# 3rd Largest Property Use Type                                 10262
# 3rd Largest Property Use Type - Gross Floor Area (ft²)        10262
# Fuel Oil #2 Use (kBtu)                                         9165
# 2nd Largest Property Use Type                                  8005
# 2nd Largest Property Use - Gross Floor Area (ft²)              8005
# Metered Areas  (Water)                                         4609
# Water Intensity (All Water Sources) (gal/ft²)                  3984
# Water Use (All Water Sources) (kgal)                           3984
# NTA                                                            2263
# Census Tract                                                   2263
# Community Board                                                2263
# Council District                                               2263
# Latitude                                                       2263
# Longitude                                                      2263
# ENERGY STAR Score                                              2104
# Weather Normalized Site Natural Gas Intensity (therms/ft²)     1963
# Weather Normalized Site Natural Gas Use (therms)               1962
# Weather Normalized Site EUI (kBtu/ft²)                         1465
# Weather Normalized Source EUI (kBtu/ft²)                       1465
# Natural Gas Use (kBtu)                                         1442
# Weather Normalized Site Electricity Intensity (kWh/ft²)         787
# Weather Normalized Site Electricity (kWh)                       786
# Electricity Use - Grid Purchase (kBtu)                          244
# Site EUI (kBtu/ft²)                                             163
# Source EUI (kBtu/ft²)                                           163
# NYC Building Identification Number (BIN)                        162
# Street Number                                                   124
# Street Name                                                     122
# DOF Gross Floor Area                                            118
# Borough                                                         118
# Water Required?                                                 118
# Direct GHG Emissions (Metric Tons CO2e)                          83
# Total GHG Emissions (Metric Tons CO2e)                           74
# Indirect GHG Emissions (Metric Tons CO2e)                        65
# Metered Areas (Energy)                                           57
# DOF Benchmarking Submission Status                               30
# NYC Borough, Block and Lot (BBL) self-reported                   11
# BBL - 10 digits                                                  11
# Largest Property Use Type - Gross Floor Area (ft²)                2
# Largest Property Use Type                                         2
# Year Built                                                        0
# List of All Property Use Types at Property                        0
# Number of Buildings - Self-reported                               0
# Occupancy                                                         0
# Address 1 (self-reported)                                         0
# Postal Code                                                       0
# Parent Property Id                                                0
# Property Name                                                     0
# Property Id                                                       0
# Order                                                             0
# Primary Property Type - Self Selected                             0
# Parent Property Name                                              0
# Release Date                                                      0
# Property GFA - Self-Reported (ft²)                                0
# dtype: int64

# %%
# 변수별 결측치 비율
ser_miss_rate = ser_miss_cnt / len(df)
ser_miss_rate
# Out:
# Fuel Oil #1 Use (kBtu)                                        0.999234
# Diesel #2 Use (kBtu)                                          0.998638
# Address 2                                                     0.982377
# Fuel Oil #5 & 6 Use (kBtu)                                    0.949430
# District Steam Use (kBtu)                                     0.920313
# Fuel Oil #4 Use (kBtu)                                        0.887536
# 3rd Largest Property Use Type                                 0.873659
# 3rd Largest Property Use Type - Gross Floor Area (ft²)        0.873659
# Fuel Oil #2 Use (kBtu)                                        0.780266
# 2nd Largest Property Use Type                                 0.681509
# 2nd Largest Property Use - Gross Floor Area (ft²)             0.681509
# Metered Areas  (Water)                                        0.392389
# Water Intensity (All Water Sources) (gal/ft²)                 0.339179
# Water Use (All Water Sources) (kgal)                          0.339179
# NTA                                                           0.192661
# Census Tract                                                  0.192661
# Community Board                                               0.192661
# Council District                                              0.192661
# Latitude                                                      0.192661
# Longitude                                                     0.192661
# ENERGY STAR Score                                             0.179125
# Weather Normalized Site Natural Gas Intensity (therms/ft²)    0.167121
# Weather Normalized Site Natural Gas Use (therms)              0.167036
# Weather Normalized Site EUI (kBtu/ft²)                        0.124723
# Weather Normalized Source EUI (kBtu/ft²)                      0.124723
# Natural Gas Use (kBtu)                                        0.122765
# Weather Normalized Site Electricity Intensity (kWh/ft²)       0.067002
# Weather Normalized Site Electricity (kWh)                     0.066916
# Electricity Use - Grid Purchase (kBtu)                        0.020773
# Site EUI (kBtu/ft²)                                           0.013877
# Source EUI (kBtu/ft²)                                         0.013877
# NYC Building Identification Number (BIN)                      0.013792
# Street Number                                                 0.010557
# Street Name                                                   0.010387
# DOF Gross Floor Area                                          0.010046
# Borough                                                       0.010046
# Water Required?                                               0.010046
# Direct GHG Emissions (Metric Tons CO2e)                       0.007066
# Total GHG Emissions (Metric Tons CO2e)                        0.006300
# Indirect GHG Emissions (Metric Tons CO2e)                     0.005534
# Metered Areas (Energy)                                        0.004853
# DOF Benchmarking Submission Status                            0.002554
# NYC Borough, Block and Lot (BBL) self-reported                0.000936
# BBL - 10 digits                                               0.000936
# Largest Property Use Type - Gross Floor Area (ft²)            0.000170
# Largest Property Use Type                                     0.000170
# Year Built                                                    0.000000
# List of All Property Use Types at Property                    0.000000
# Number of Buildings - Self-reported                           0.000000
# Occupancy                                                     0.000000
# Address 1 (self-reported)                                     0.000000
# Postal Code                                                   0.000000
# Parent Property Id                                            0.000000
# Property Name                                                 0.000000
# Property Id                                                   0.000000
# Order                                                         0.000000
# Primary Property Type - Self Selected                         0.000000
# Parent Property Name                                          0.000000
# Release Date                                                  0.000000
# Property GFA - Self-Reported (ft²)                            0.000000
# dtype: float64

# %%
# 결측 비율이 50% 이상인 변수만 제거
threshold = 0.5 # 변수 제거의 임계치
print(ser_miss_rate[ser_miss_rate > 0.5])

del_list = ser_miss_rate[ser_miss_rate > 0.5].index
print(f'제거 대상 변수: {del_list}')
# Out:
# Fuel Oil #1 Use (kBtu)                                    0.999234
# Diesel #2 Use (kBtu)                                      0.998638
# Address 2                                                 0.982377
# Fuel Oil #5 & 6 Use (kBtu)                                0.949430
# District Steam Use (kBtu)                                 0.920313
# Fuel Oil #4 Use (kBtu)                                    0.887536
# 3rd Largest Property Use Type                             0.873659
# 3rd Largest Property Use Type - Gross Floor Area (ft²)    0.873659
# Fuel Oil #2 Use (kBtu)                                    0.780266
# 2nd Largest Property Use Type                             0.681509
# 2nd Largest Property Use - Gross Floor Area (ft²)         0.681509
# dtype: float64
# 제거 대상 변수: Index(['Fuel Oil #1 Use (kBtu)', 'Diesel #2 Use (kBtu)', 'Address 2',
#        'Fuel Oil #5 & 6 Use (kBtu)', 'District Steam Use (kBtu)',
#        'Fuel Oil #4 Use (kBtu)', '3rd Largest Property Use Type',
#        '3rd Largest Property Use Type - Gross Floor Area (ft²)',
#        'Fuel Oil #2 Use (kBtu)', '2nd Largest Property Use Type',
#        '2nd Largest Property Use - Gross Floor Area (ft²)'],
#       dtype='str')

# %%
# 변수 제거
df.drop(columns=del_list, inplace=True)
df.head()
# Out:
#    Order  Property Id                                 Property Name  \
# 0      1        13286                                       201/205
# 1      2        28400                    NYP Columbia (West Campus)
# 2      3      4778226                                 MSCHoNY North
# 3      4      4778267  Herbert Irving Pavilion & Millstein Hospital
# 4      5      4778288                               Neuro Institute
#
#   Parent Property Id        Parent Property Name BBL - 10 digits  \
# 0              13286                     201/205      1013160001
# 1              28400  NYP Columbia (West Campus)      1021380040
# 2              28400  NYP Columbia (West Campus)      1021380030
# 3              28400  NYP Columbia (West Campus)      1021390001
# 4              28400  NYP Columbia (West Campus)      1021390085
#
#   NYC Borough, Block and Lot (BBL) self-reported  \
# 0                                     1013160001
# 1                                   1-02138-0040
# 2                                   1-02138-0030
# 3                                   1-02139-0001
# 4                                   1-02139-0085
#
#             NYC Building Identification Number (BIN)  \
# 0                                            1037549
# 1  1084198; 1084387;1084385; 1084386; 1084388; 10...
# 2                                            1063380
# 3                                   1087281; 1076746
# 4                                            1063403
#
#   Address 1 (self-reported) Postal Code  ... Source EUI (kBtu/ft²)  \
# 0  201/205  East  42nd  st.       10017  ...                 619.4
# 1          622 168th Street       10032  ...                 404.3
# 2             3975 Broadway       10032  ...                   NaN
# 3   161 Fort Washington Ave       10032  ...                   NaN
# 4     710 West 168th Street       10032  ...                   NaN
#
#              Release Date Water Required?  DOF Benchmarking Submission Status  \
# 0  05/01/2017 05:32:03 PM              No                       In Compliance
# 1  04/27/2017 11:23:27 AM              No                       In Compliance
# 2  04/27/2017 11:23:27 AM              No                       In Compliance
# 3  04/27/2017 11:23:27 AM              No                       In Compliance
# 4  04/27/2017 11:23:27 AM              No                       In Compliance
#
#     Latitude  Longitude Community Board Council District  Census Tract  \
# 0  40.750791 -73.973963             6.0              4.0          88.0
# 1  40.841402 -73.942568            12.0             10.0         251.0
# 2  40.840427 -73.940249            12.0             10.0         251.0
# 3  40.840746 -73.942854            12.0             10.0         255.0
# 4  40.841559 -73.942528            12.0             10.0         255.0
#
#                                                  NTA
# 0  Turtle Bay-East Midtown                       ...
# 1  Washington Heights South                      ...
# 2  Washington Heights South                      ...
# 3  Washington Heights South                      ...
# 4  Washington Heights South                      ...
#
# [5 rows x 49 columns]

# %% [markdown]
# ### **2. 탐색적 데이터 분석**

# %%
# 시각화 옵션
# %matplotlib
# %config InlineBackend.figure_format = 'jpg'

from matplotlib import pyplot as plt
plt.rcParams['figure.figsize'] = [10, 5]
plt.ion() # 인터랙티브 시각화

import seaborn as sns
sns.set()  # 시각화 스타일 설정
# Out:
# Using matplotlib backend: module://matplotlib_inline.backend_inline

# %%
# 변수명 간소화 (ENERGY STAR Score)
df = df.rename(columns = {'ENERGY STAR Score': 'Score'})

# Energy Star Score 히스토그램 시각화
plt.style.use('fivethirtyeight')
plt.hist(df['Score'].dropna(), bins = 100, edgecolor = 'k')
plt.xlabel('Score')
plt.ylabel('Number of Buildings')
plt.title('Energy Star Score Distribution')
plt.show()

# %%
# Site EUI 히스토그램 시각화
plt.hist(df['Site EUI (kBtu/ft²)'].dropna(), bins = 20, edgecolor = 'black')
plt.xlabel('Site EUI')
plt.ylabel('Count')
plt.title('Site EUI Distribution')
# Out:
# Text(0.5, 1.0, 'Site EUI Distribution')

# %% [markdown]
# Site EUI 히스토그램이 제대로 보이지 않음 ${\rightarrow}$ 기술 통계량을 확인해보자

# %%
# Site EUI 기술 통계
df['Site EUI (kBtu/ft²)'].describe()
# Out:
# count     11583.000000
# mean        280.071484
# std        8607.178877
# min           0.000000
# 25%          61.800000
# 50%          78.500000
# 75%          97.600000
# max      869265.000000
# Name: Site EUI (kBtu/ft²), dtype: float64

# %%
# 상위 10개의 Site EUI 값
df['Site EUI (kBtu/ft²)'].dropna().sort_values().tail(10)
# Out:
# 3173     51328.8
# 3170     51831.2
# 3383     78360.1
# 8269     84969.6
# 3263     95560.2
# 8268    103562.7
# 8174    112173.6
# 3898    126307.4
# 7       143974.4
# 8068    869265.0
# Name: Site EUI (kBtu/ft²), dtype: float64

# %%
# 가장 큰 Site EUI 값의 빌딩
df.loc[8068]
# Out:
# Order                                                                                                      9984
# Property Id                                                                                             4414323
# Property Name                                                                                      234 Skillman
# Parent Property Id                                                          Not Applicable: Standalone Property
# Parent Property Name                                                        Not Applicable: Standalone Property
# BBL - 10 digits                                                                                      3028937502
# NYC Borough, Block and Lot (BBL) self-reported                                                       3028937502
# NYC Building Identification Number (BIN)                                                      3390250 , 3338313
# Address 1 (self-reported)                                                                   234 Skillman avenue
# Postal Code                                                                                               11211
# Street Number                                                                                               234
# Street Name                                                                                     SKILLMAN AVENUE
# Borough                                                                                                Brooklyn
# DOF Gross Floor Area                                                                                    61811.0
# Primary Property Type - Self Selected                                                       Multifamily Housing
# List of All Property Use Types at Property                                                  Multifamily Housing
# Largest Property Use Type                                                                   Multifamily Housing
# Largest Property Use Type - Gross Floor Area (ft²)                                                        56900
# Year Built                                                                                                 2004
# Number of Buildings - Self-reported                                                                           1
# Occupancy                                                                                                    90
# Metered Areas (Energy)                                                                           Whole Building
# Metered Areas  (Water)                                                                                      NaN
# Score                                                                                                       1.0
# Site EUI (kBtu/ft²)                                                                                    869265.0
# Weather Normalized Site EUI (kBtu/ft²)                                                                 939329.0
# Weather Normalized Site Electricity Intensity (kWh/ft²)                                                     9.9
# Weather Normalized Site Natural Gas Intensity (therms/ft²)                                               9393.0
# Weather Normalized Source EUI (kBtu/ft²)                                                               986366.0
# Natural Gas Use (kBtu)                                                                            49459193300.0
# Weather Normalized Site Natural Gas Use (therms)                                                    534458968.8
# Electricity Use - Grid Purchase (kBtu)                                                                1983655.6
# Weather Normalized Site Electricity (kWh)                                                              563239.6
# Total GHG Emissions (Metric Tons CO2e)                                                                2627199.1
# Direct GHG Emissions (Metric Tons CO2e)                                                               2627015.0
# Indirect GHG Emissions (Metric Tons CO2e)                                                                 184.1
# Property GFA - Self-Reported (ft²)                                                                        56900
# Water Use (All Water Sources) (kgal)                                                                     2547.9
# Water Intensity (All Water Sources) (gal/ft²)                                                             44.78
# Source EUI (kBtu/ft²)                                                                                  912801.1
# Release Date                                                                             05/01/2017 11:34:14 PM
# Water Required?                                                                                             NaN
# DOF Benchmarking Submission Status                                                                In Compliance
# Latitude                                                                                              40.716233
# Longitude                                                                                             -73.94141
# Community Board                                                                                             1.0
# Council District                                                                                           34.0
# Census Tract                                                                                              477.0
# NTA                                                           East Williamsburg                             ...
# Name: 8068, dtype: object

# %% [markdown]
# **[데이터 정리]** Site EUI 값을 중심으로 한 IQR 기반 **이상치 제거**

# %%
# Q1, Q3 계산
q1 = df['Site EUI (kBtu/ft²)'].quantile(0.25)
q3 = df['Site EUI (kBtu/ft²)'].quantile(0.75)

print('Site EUI, Q1 =', q1)
print('Site EUI, Q3 =', q3)
# Out:
# Site EUI, Q1 = 61.8
# Site EUI, Q3 = 97.6

# %%
# IQR (사분위수 범위)
iqr = q3-q1

"""
상한/하한 계산 (이상치 계수 3 적용)
 - 1.5: mild outliers
 - 3: extreme outliers
"""

upper_fence = q3 + 3*iqr # 상한
lower_fence = q1 - 3*iqr # 하한

print('IQR =', iqr)
print('Upper fence =', upper_fence)
print('Lower fence =', lower_fence)
# Out:
# IQR = 35.8
# Upper fence = 205.0
# Lower fence = -45.599999999999994

# %%
# 이상치 제거
df = df[ (df['Site EUI (kBtu/ft²)'] < upper_fence) &
      (df['Site EUI (kBtu/ft²)'] > lower_fence) ]

df['Site EUI (kBtu/ft²)'].shape
# Out:
# (11319,)

# %%
# Site EUI 히스토그램 시각화 (이상치 제거 후)

plt.hist(df['Site EUI (kBtu/ft²)'].dropna(), bins = 20, edgecolor = 'black')
plt.xlabel('Site EUI')
plt.ylabel('Count')
plt.title('Site EUI Distribution')
# Out:
# Text(0.5, 1.0, 'Site EUI Distribution')

# %% [markdown]
# **[데이터 탐색]** 타겟 변수(Energy Star Score)와 범주형 변수와의 상관관계

# %% [markdown]
# 범주형 변수: **Largest Property Use Type** (주 용도에 따른 빌딩 유형)

# %%
# 빌딩 유형과의 상관관계
df_has_score = df.dropna(subset=['Score'])  # 스코어가 있는 데이터만 선택
types = df_has_score['Largest Property Use Type'].value_counts() # 빌딩 유형별 빈도 계산
types
# Out:
# Largest Property Use Type
# Multifamily Housing                      7464
# Office                                   1157
# Hotel                                     202
# Non-Refrigerated Warehouse                156
# K-12 School                                97
# Residence Hall/Dormitory                   96
# Senior Care Community                      85
# Distribution Center                        61
# Retail Store                               57
# Medical Office                             23
# Hospital (General Medical & Surgical)      15
# Financial Office                           12
# Supermarket/Grocery Store                  10
# Worship Facility                            9
# Refrigerated Warehouse                      8
# Parking                                     3
# Wholesale Club/Supercenter                  3
# Courthouse                                  2
# Bank Branch                                 1
# Name: count, dtype: int64

# %%
# 빈도 100 이상인 빌딩 유형
types_100 = types[types.values > 100].index
types_100
# Out:
# Index(['Multifamily Housing', 'Office', 'Hotel', 'Non-Refrigerated Warehouse'], dtype='str', name='Largest Property Use Type')

# %%
# 빌딩 유형 밀도 그래프 시각화

for b_type in types_100:
    subset = df[df['Largest Property Use Type'] == b_type]
    sns.kdeplot(subset['Score'].dropna(),
               label=b_type, alpha=0.8)

plt.xlabel('Energy Star Scores')
plt.ylabel('Density')
plt.title('Density Plot of Energy Star Scores by Building Type')
plt.legend(loc='best')

# %% [markdown]
# 범주형 변수: **Borough** (빌딩 자치구의 위치)

# %%
boroughs = df_has_score['Borough'].value_counts()  # 자치구별 빈도 계산
print(boroughs)

boroughs = boroughs.index
print(boroughs)
# Out:
# Borough
# Manhattan        3985
# Brooklyn         1947
# Queens           1707
# Bronx            1655
# Staten Island     119
# Name: count, dtype: int64
# Index(['Manhattan', 'Brooklyn', 'Queens', 'Bronx', 'Staten Island'], dtype='str', name='Borough')

# %%
# 자치구 밀도 그래프 시각화
for borough in boroughs:
    subset = df[df['Borough'] == borough]
    sns.kdeplot(subset['Score'].dropna(),
               label=borough)

plt.xlabel("Energy Star Scores")
plt.ylabel('Density')
plt.title("Density Plot of Energy Star Scores by Borough")
plt.legend(loc='best')

# %% [markdown]
# **[데이터 탐색]** 타겟 변수(Energy Star Score)와 수치형 변수와의 상관관계

# %%
# 수치형 데이터만 선택
numeric_df = df.select_dtypes(include=['int64', 'float64'])
numeric_df.head()
# Out:
#     Order  Property Id  DOF Gross Floor Area  Year Built  \
# 12     15      2637863                   NaN        1903
# 17     20      2777309                   NaN        1907
# 18     21      2780056                   NaN        1939
# 19     22      4988574              179130.0        1939
# 20     23      4988569              102150.0        1939
#
#     Number of Buildings - Self-reported  Occupancy  Score  \
# 12                                    2        100   93.0
# 17                                    7        100    NaN
# 18                                    2        100   72.0
# 19                                    1        100   67.0
# 20                                    1        100   80.0
#
#     Site EUI (kBtu/ft²)  Weather Normalized Site EUI (kBtu/ft²)  \
# 12                 32.0                                     NaN
# 17                120.0                                   125.2
# 18                 76.2                                    79.9
# 19                 75.7                                    79.0
# 20                 77.1                                    82.7
#
#     Weather Normalized Site Electricity Intensity (kWh/ft²)  ...  \
# 12                                                7.5        ...
# 17                                                8.7        ...
# 18                                                3.5        ...
# 19                                                4.0        ...
# 20                                                2.6        ...
#
#     Indirect GHG Emissions (Metric Tons CO2e)  \
# 12                                     1043.2
# 17                                     1666.5
# 18                                      368.3
# 19                                      267.9
# 20                                      100.4
#
#     Property GFA - Self-Reported (ft²)  Water Use (All Water Sources) (kgal)  \
# 12                              432503                               22061.0
# 17                              598000                                   NaN
# 18                              321464                                5915.6
# 19                              204720                                   NaN
# 20                              116744                                   NaN
#
#     Water Intensity (All Water Sources) (gal/ft²)  Source EUI (kBtu/ft²)  \
# 12                                          51.01                   87.9
# 17                                            NaN                  188.7
# 18                                          18.40                  103.3
# 19                                            NaN                  106.6
# 20                                            NaN                   97.7
#
#      Latitude  Longitude  Community Board  Council District  Census Tract
# 12        NaN        NaN              NaN               NaN           NaN
# 17        NaN        NaN              NaN               NaN           NaN
# 18        NaN        NaN              NaN               NaN           NaN
# 19  40.857943 -73.934962             12.0              10.0         281.0
# 20  40.858256 -73.934734             12.0              10.0         281.0
#
# [5 rows x 28 columns]

# %%
# 타겟과의 수치형 상관계수
corr = numeric_df.corr()['Score'].sort_values()
corr
# Out:
# Site EUI (kBtu/ft²)                                          -0.723864
# Weather Normalized Site EUI (kBtu/ft²)                       -0.713993
# Weather Normalized Source EUI (kBtu/ft²)                     -0.645542
# Source EUI (kBtu/ft²)                                        -0.641037
# Weather Normalized Site Electricity Intensity (kWh/ft²)      -0.358394
# Weather Normalized Site Natural Gas Intensity (therms/ft²)   -0.346046
# Direct GHG Emissions (Metric Tons CO2e)                      -0.147792
# Weather Normalized Site Natural Gas Use (therms)             -0.135211
# Natural Gas Use (kBtu)                                       -0.133648
# Year Built                                                   -0.121249
# Total GHG Emissions (Metric Tons CO2e)                       -0.113136
# Electricity Use - Grid Purchase (kBtu)                       -0.050639
# Weather Normalized Site Electricity (kWh)                    -0.048207
# Latitude                                                     -0.048196
# Property Id                                                  -0.046605
# Indirect GHG Emissions (Metric Tons CO2e)                    -0.043982
# Longitude                                                    -0.037455
# Occupancy                                                    -0.033215
# Number of Buildings - Self-reported                          -0.022407
# Water Use (All Water Sources) (kgal)                         -0.013681
# Water Intensity (All Water Sources) (gal/ft²)                -0.012148
# Census Tract                                                 -0.002299
# DOF Gross Floor Area                                          0.013001
# Property GFA - Self-Reported (ft²)                            0.017360
# Order                                                         0.036827
# Community Board                                               0.056612
# Council District                                              0.061639
# Score                                                         1.000000
# Name: Score, dtype: float64

# %%
"""
Two-Variable Plots
- Variable 1: Site EUI
- Variable 2: Largest Property Use Type
- Target: Energy Star Score
"""

# Extract the building types
df['Largest Property Use Type'] = df.dropna(subset = ['Score'])['Largest Property Use Type']

# %%
# Limit to building types with more than 100 observations
print(types_100)
df = df[df['Largest Property Use Type'].isin(types_100)]
df.shape
# Out:
# Index(['Multifamily Housing', 'Office', 'Hotel', 'Non-Refrigerated Warehouse'], dtype='str', name='Largest Property Use Type')
# (8979, 49)

# %%
# Scatterplot of Score vs Site EUI

sns.lmplot(
    data=df,
    x='Site EUI (kBtu/ft²)', 
    y='Score',
    hue='Largest Property Use Type',
    scatter_kws={'alpha': 0.8}, 
    fit_reg=False,    
    aspect=1.2
)

plt.xlabel('Site EUI')
plt.ylabel('Enery Star Score')
plt.title('Energy Star Score vs Site EUI')
# Out:
# Text(0.5, 1.0, 'Energy Star Score vs Site EUI')

# %%
"""
Pairs Plot
"""

# Select the columns to plot
df_plot = df[['Score',
              'Site EUI (kBtu/ft²)',
              'Weather Normalized Site EUI (kBtu/ft²)',
              'Weather Normalized Source EUI (kBtu/ft²)',
              'Source EUI (kBtu/ft²)',
              'Weather Normalized Site Electricity Intensity (kWh/ft²)',
              'Total GHG Emissions (Metric Tons CO2e)']]

# %%
# Rename columns
df_plot.rename(columns={'Site EUI (kBtu/ft²)':
                        'Site EUI',
                       'Weather Normalized Site EUI (kBtu/ft²)':
                        'Weather Norm Site EUI',
                       'Weather Normalized Source EUI (kBtu/ft²)':
                        'Weather Norm Src EUI)',
                       'Source EUI (kBtu/ft²)':
                        'Source EUI',
                       'Weather Normalized Site Electricity Intensity (kWh/ft²)':
                        'Weather Norm Site Elec Intensity',
                       'Total GHG Emissions (Metric Tons CO2e)':
                       'Total GHG Emissions'}, inplace=True)

# %%
# Replace the inf with nan
df_plot = df_plot.replace({np.inf: np.nan, -np.inf: np.nan})

# Drop NA values
df_plot.dropna(inplace=True)

# %%
# Function to calculate correlation coefficient between two columns

# Plot a correlation matrix using pairplot
sns.pairplot(df_plot, kind='reg', diag_kind='kde', 
            plot_kws={'scatter_kws': {'alpha': 0.1}})

# %%
"""
Feature Extraction & Selection
"""

# Create columns with square root and log of numeric columns

df_numeric = df.select_dtypes('number') # select the numeric columns

for col in df_numeric.columns:
    # Skip the Energy Star Score column
    if col == 'Score':
        continue
    else:
        df_numeric['sqrt_' + col] = np.sqrt(df_numeric[col])
        df_numeric['log_' + col] = np.log(df_numeric[col])
# Out:
# c:\Users\김태겸\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# c:\Users\김태겸\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: invalid value encountered in sqrt
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# c:\Users\김태겸\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
df_numeric.head()
# Out:
#     Order  Property Id  DOF Gross Floor Area  Year Built  \
# 12     15      2637863                   NaN        1903
# 18     21      2780056                   NaN        1939
# 19     22      4988574              179130.0        1939
# 20     23      4988569              102150.0        1939
# 21     24      2806486                   NaN        1911
#
#     Number of Buildings - Self-reported  Occupancy  Score  \
# 12                                    2        100   93.0
# 18                                    2        100   72.0
# 19                                    1        100   67.0
# 20                                    1        100   80.0
# 21                                    2        100  100.0
#
#     Site EUI (kBtu/ft²)  Weather Normalized Site EUI (kBtu/ft²)  \
# 12                 32.0                                     NaN
# 18                 76.2                                    79.9
# 19                 75.7                                    79.0
# 20                 77.1                                    82.7
# 21                 68.0                                     NaN
#
#     Weather Normalized Site Electricity Intensity (kWh/ft²)  ...  \
# 12                                                7.5        ...
# 18                                                3.5        ...
# 19                                                4.0        ...
# 20                                                2.6        ...
# 21                                                6.1        ...
#
#     sqrt_Latitude  log_Latitude  sqrt_Longitude  log_Longitude  \
# 12            NaN           NaN             NaN            NaN
# 18            NaN           NaN             NaN            NaN
# 19       6.392022      3.710101             NaN            NaN
# 20       6.392046      3.710109             NaN            NaN
# 21            NaN           NaN             NaN            NaN
#
#     sqrt_Community Board  log_Community Board  sqrt_Council District  \
# 12                   NaN                  NaN                    NaN
# 18                   NaN                  NaN                    NaN
# 19              3.464102             2.484907               3.162278
# 20              3.464102             2.484907               3.162278
# 21                   NaN                  NaN                    NaN
#
#     log_Council District  sqrt_Census Tract  log_Census Tract
# 12                   NaN                NaN               NaN
# 18                   NaN                NaN               NaN
# 19              2.302585          16.763055          5.638355
# 20              2.302585          16.763055          5.638355
# 21                   NaN                NaN               NaN
#
# [5 rows x 82 columns]

# %%
# One-hot encoding for the categorical columns

df_categoric = df[['Borough', 'Largest Property Use Type']]  # Select the categorical columns
df_categoric.head()
# Out:
#       Borough Largest Property Use Type
# 12        NaN       Multifamily Housing
# 18        NaN       Multifamily Housing
# 19  Manhattan       Multifamily Housing
# 20  Manhattan       Multifamily Housing
# 21        NaN       Multifamily Housing

# %%
df_categoric = pd.get_dummies(df_categoric)  # One-hot encoding
df_categoric.head()
# Out:
#     Borough_Bronx  Borough_Brooklyn  Borough_Manhattan  Borough_Queens  \
# 12          False             False              False           False
# 18          False             False              False           False
# 19          False             False               True           False
# 20          False             False               True           False
# 21          False             False              False           False
#
#     Borough_Staten Island  Largest Property Use Type_Hotel  \
# 12                  False                            False
# 18                  False                            False
# 19                  False                            False
# 20                  False                            False
# 21                  False                            False
#
#     Largest Property Use Type_Multifamily Housing  \
# 12                                           True
# 18                                           True
# 19                                           True
# 20                                           True
# 21                                           True
#
#     Largest Property Use Type_Non-Refrigerated Warehouse  \
# 12                                              False
# 18                                              False
# 19                                              False
# 20                                              False
# 21                                              False
#
#     Largest Property Use Type_Office
# 12                             False
# 18                             False
# 19                             False
# 20                             False
# 21                             False

# %%
# Join the two DataFrames using concat
df_transformed = pd.concat([df_numeric, df_categoric], axis=1)

# Drop buildings without an Energy Star Score
df_transformed.dropna(subset=['Score'], inplace=True)

# %%
df_transformed.shape
# Out:
# (8979, 91)

# %%
df_transformed.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 8979 entries, 12 to 11745
# Data columns (total 91 columns):
#  #   Column                                                           Non-Null Count  Dtype
# ---  ------                                                           --------------  -----
#  0   Order                                                            8979 non-null   int64
#  1   Property Id                                                      8979 non-null   int64
#  2   DOF Gross Floor Area                                             8942 non-null   float64
#  3   Year Built                                                       8979 non-null   int64
#  4   Number of Buildings - Self-reported                              8979 non-null   int64
#  5   Occupancy                                                        8979 non-null   int64
#  6   Score                                                            8979 non-null   float64
#  7   Site EUI (kBtu/ft²)                                              8979 non-null   float64
#  8   Weather Normalized Site EUI (kBtu/ft²)                           7962 non-null   float64
#  9   Weather Normalized Site Electricity Intensity (kWh/ft²)          8542 non-null   float64
#  10  Weather Normalized Site Natural Gas Intensity (therms/ft²)       7660 non-null   float64
#  11  Weather Normalized Source EUI (kBtu/ft²)                         7962 non-null   float64
#  12  Natural Gas Use (kBtu)                                           8036 non-null   float64
#  13  Weather Normalized Site Natural Gas Use (therms)                 7660 non-null   float64
#  14  Electricity Use - Grid Purchase (kBtu)                           8915 non-null   float64
#  15  Weather Normalized Site Electricity (kWh)                        8542 non-null   float64
#  16  Total GHG Emissions (Metric Tons CO2e)                           8976 non-null   float64
#  17  Direct GHG Emissions (Metric Tons CO2e)                          8966 non-null   float64
#  18  Indirect GHG Emissions (Metric Tons CO2e)                        8970 non-null   float64
#  19  Property GFA - Self-Reported (ft²)                               8979 non-null   int64
#  20  Water Use (All Water Sources) (kgal)                             6114 non-null   float64
#  21  Water Intensity (All Water Sources) (gal/ft²)                    6114 non-null   float64
#  22  Source EUI (kBtu/ft²)                                            8979 non-null   float64
#  23  Latitude                                                         7301 non-null   float64
#  24  Longitude                                                        7301 non-null   float64
#  25  Community Board                                                  7301 non-null   float64
#  26  Council District                                                 7301 non-null   float64
#  27  Census Tract                                                     7301 non-null   float64
#  28  sqrt_Order                                                       8979 non-null   float64
#  29  log_Order                                                        8979 non-null   float64
#  30  sqrt_Property Id                                                 8979 non-null   float64
#  31  log_Property Id                                                  8979 non-null   float64
#  32  sqrt_DOF Gross Floor Area                                        8942 non-null   float64
#  33  log_DOF Gross Floor Area                                         8942 non-null   float64
#  34  sqrt_Year Built                                                  8979 non-null   float64
#  35  log_Year Built                                                   8979 non-null   float64
#  36  sqrt_Number of Buildings - Self-reported                         8979 non-null   float64
#  37  log_Number of Buildings - Self-reported                          8979 non-null   float64
#  38  sqrt_Occupancy                                                   8979 non-null   float64
#  39  log_Occupancy                                                    8979 non-null   float64
#  40  sqrt_Site EUI (kBtu/ft²)                                         8979 non-null   float64
#  41  log_Site EUI (kBtu/ft²)                                          8979 non-null   float64
#  42  sqrt_Weather Normalized Site EUI (kBtu/ft²)                      7962 non-null   float64
#  43  log_Weather Normalized Site EUI (kBtu/ft²)                       7962 non-null   float64
#  44  sqrt_Weather Normalized Site Electricity Intensity (kWh/ft²)     8542 non-null   float64
#  45  log_Weather Normalized Site Electricity Intensity (kWh/ft²)      8542 non-null   float64
#  46  sqrt_Weather Normalized Site Natural Gas Intensity (therms/ft²)  7660 non-null   float64
#  47  log_Weather Normalized Site Natural Gas Intensity (therms/ft²)   7660 non-null   float64
#  48  sqrt_Weather Normalized Source EUI (kBtu/ft²)                    7962 non-null   float64
#  49  log_Weather Normalized Source EUI (kBtu/ft²)                     7962 non-null   float64
#  50  sqrt_Natural Gas Use (kBtu)                                      8036 non-null   float64
#  51  log_Natural Gas Use (kBtu)                                       8036 non-null   float64
#  52  sqrt_Weather Normalized Site Natural Gas Use (therms)            7660 non-null   float64
#  53  log_Weather Normalized Site Natural Gas Use (therms)             7660 non-null   float64
#  54  sqrt_Electricity Use - Grid Purchase (kBtu)                      8915 non-null   float64
#  55  log_Electricity Use - Grid Purchase (kBtu)                       8915 non-null   float64
#  56  sqrt_Weather Normalized Site Electricity (kWh)                   8542 non-null   float64
#  57  log_Weather Normalized Site Electricity (kWh)                    8542 non-null   float64
#  58  sqrt_Total GHG Emissions (Metric Tons CO2e)                      8976 non-null   float64
#  59  log_Total GHG Emissions (Metric Tons CO2e)                       8976 non-null   float64
#  60  sqrt_Direct GHG Emissions (Metric Tons CO2e)                     8966 non-null   float64
#  61  log_Direct GHG Emissions (Metric Tons CO2e)                      8966 non-null   float64
#  62  sqrt_Indirect GHG Emissions (Metric Tons CO2e)                   8970 non-null   float64
#  63  log_Indirect GHG Emissions (Metric Tons CO2e)                    8970 non-null   float64
#  64  sqrt_Property GFA - Self-Reported (ft²)                          8979 non-null   float64
#  65  log_Property GFA - Self-Reported (ft²)                           8979 non-null   float64
#  66  sqrt_Water Use (All Water Sources) (kgal)                        6114 non-null   float64
#  67  log_Water Use (All Water Sources) (kgal)                         6114 non-null   float64
#  68  sqrt_Water Intensity (All Water Sources) (gal/ft²)               6114 non-null   float64
#  69  log_Water Intensity (All Water Sources) (gal/ft²)                6114 non-null   float64
#  70  sqrt_Source EUI (kBtu/ft²)                                       8979 non-null   float64
#  71  log_Source EUI (kBtu/ft²)                                        8979 non-null   float64
#  72  sqrt_Latitude                                                    7301 non-null   float64
#  73  log_Latitude                                                     7301 non-null   float64
#  74  sqrt_Longitude                                                   0 non-null      float64
#  75  log_Longitude                                                    0 non-null      float64
#  76  sqrt_Community Board                                             7301 non-null   float64
#  77  log_Community Board                                              7301 non-null   float64
#  78  sqrt_Council District                                            7301 non-null   float64
#  79  log_Council District                                             7301 non-null   float64
#  80  sqrt_Census Tract                                                7301 non-null   float64
#  81  log_Census Tract                                                 7301 non-null   float64
#  82  Borough_Bronx                                                    8979 non-null   bool
#  83  Borough_Brooklyn                                                 8979 non-null   bool
#  84  Borough_Manhattan                                                8979 non-null   bool
#  85  Borough_Queens                                                   8979 non-null   bool
#  86  Borough_Staten Island                                            8979 non-null   bool
#  87  Largest Property Use Type_Hotel                                  8979 non-null   bool
#  88  Largest Property Use Type_Multifamily Housing                    8979 non-null   bool
#  89  Largest Property Use Type_Non-Refrigerated Warehouse             8979 non-null   bool
#  90  Largest Property Use Type_Office                                 8979 non-null   bool
# dtypes: bool(9), float64(76), int64(6)
# memory usage: 5.8 MB

# %%
"""
Remove Collinear Features
"""

df_plot = df[['Weather Normalized Site EUI (kBtu/ft²)', 
              'Site EUI (kBtu/ft²)']].dropna()

plt.plot(df_plot['Site EUI (kBtu/ft²)'], 
         df_plot['Weather Normalized Site EUI (kBtu/ft²)'], 
         'bo')
plt.xlabel('Site EUI')
plt.ylabel('Weather Norm EUI')
plt.title('Weather Norm EUI vs Site EUI, R = %0.4f' % 
          np.corrcoef(df[['Weather Normalized Site EUI (kBtu/ft²)',
                          'Site EUI (kBtu/ft²)']].dropna(), rowvar=False)[0][1]);

# %%
def remove_collinear_features(x, threshold):
    '''
    Objective:
        Remove collinear features in a dataframe with a correlation coefficient
        greater than the threshold. Removing collinear features can help a model
        to generalize and improves the interpretability of the model.
        
    Inputs: 
        threshold: any features with correlations greater than this value are removed
    
    Output: 
        dataframe that contains only the non-highly-collinear features
    '''
    
    # Dont want to remove correlations between Energy Star Score
    y = x['Score']
    x = x.drop(columns = ['Score'])
    
    # Calculate the correlation matrix
    corr_matrix = x.corr()
    iters = range(len(corr_matrix.columns) - 1)
    drop_cols = []

    # Iterate through the correlation matrix and compare correlations
    for i in iters:
        for j in range(i):
            item = corr_matrix.iloc[j:(j+1), (i+1):(i+2)]
            col = item.columns
            row = item.index
            val = abs(item.values)
            
            # If correlation exceeds the threshold
            if val >= threshold:
                # Print the correlated features and the correlation value
                # print(col.values[0], "|", row.values[0], "|", round(val[0][0], 2))
                drop_cols.append(col.values[0])

    # Drop one of each pair of correlated columns
    drops = set(drop_cols)
    x = x.drop(columns = drops)
    x = x.drop(columns = ['Weather Normalized Site EUI (kBtu/ft²)', 
                          'Water Use (All Water Sources) (kgal)',
                          'log_Water Use (All Water Sources) (kgal)',
                          'Largest Property Use Type - Gross Floor Area (ft²)'], errors='ignore')
    
    # Add the score back in to the data
    x['Score'] = y
               
    return x

# %%
# Remove the collinear features above a specified correlation coefficient
collinear_threshold = 0.6
features = remove_collinear_features(df_transformed, collinear_threshold)

# %%
# Remove any columns with all na values
features.dropna(axis=1, how = 'all', inplace=True)
features.shape
# Out:
# (8979, 22)

# %%
features.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 8979 entries, 12 to 11745
# Data columns (total 22 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   Order                                                       8979 non-null   int64
#  1   Property Id                                                 8979 non-null   int64
#  2   DOF Gross Floor Area                                        8942 non-null   float64
#  3   Year Built                                                  8979 non-null   int64
#  4   Number of Buildings - Self-reported                         8979 non-null   int64
#  5   Occupancy                                                   8979 non-null   int64
#  6   Site EUI (kBtu/ft²)                                         8979 non-null   float64
#  7   Weather Normalized Site Electricity Intensity (kWh/ft²)     8542 non-null   float64
#  8   Weather Normalized Site Natural Gas Intensity (therms/ft²)  7660 non-null   float64
#  9   Natural Gas Use (kBtu)                                      8036 non-null   float64
#  10  Weather Normalized Site Natural Gas Use (therms)            7660 non-null   float64
#  11  Water Intensity (All Water Sources) (gal/ft²)               6114 non-null   float64
#  12  Latitude                                                    7301 non-null   float64
#  13  Longitude                                                   7301 non-null   float64
#  14  Community Board                                             7301 non-null   float64
#  15  Census Tract                                                7301 non-null   float64
#  16  log_Direct GHG Emissions (Metric Tons CO2e)                 8966 non-null   float64
#  17  Borough_Staten Island                                       8979 non-null   bool
#  18  Largest Property Use Type_Hotel                             8979 non-null   bool
#  19  Largest Property Use Type_Multifamily Housing               8979 non-null   bool
#  20  Largest Property Use Type_Non-Refrigerated Warehouse        8979 non-null   bool
#  21  Score                                                       8979 non-null   float64
# dtypes: bool(4), float64(13), int64(5)
# memory usage: 1.3 MB

# %%
"""
Split Into Training and Testing Sets
"""

# Splitting data into training and testing
from sklearn.model_selection import train_test_split

# Separate out the features and targets
targets = pd.DataFrame(features['Score']) # y: vector
features = features.drop(columns='Score') # X: matrix

# Replace the inf and -inf with nan (required for later imputation)
features = features.replace({np.inf: np.nan, -np.inf: np.nan})

# Handle the missing values with imputations
features.interpolate(inplace=True)
features.bfill(inplace=True)

# Split into 70% training and 30% testing set
X_train, X_test, y_train, y_test = train_test_split(
    features, targets, test_size = 0.3, random_state = 42)

print(X_train.shape)
print(X_test.shape)
print(y_train.shape) # 학습용 정답지
print(y_test.shape) # 테스트용 정답
# Out:
# (6285, 21)
# (2694, 21)
# (6285, 1)
# (2694, 1)

# %%
# Train the model

from sklearn.ensemble import RandomForestRegressor

model = RandomForestRegressor()
model.fit(X_train, y_train)
# Out:
# c:\Users\김태겸\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py:1336: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestRegressor()

# %%
# Predict scores
y_hat = model.predict(X_test) 
print(y_test.values.reshape(-1), y_hat)
# Out:
# [82. 23. 44. ... 78. 87. 78.] [74.75 30.76 45.64 ... 55.88 82.15 72.59]

# %%
from sklearn.metrics import mean_absolute_error

mae = mean_absolute_error(y_test, y_hat)

# %%
print("Baseline Performance on the test set: MAE = %0.4f" % mae)
# Out:
# Baseline Performance on the test set: MAE = 9.2678

# %%
plt.plot(y_test.values.reshape(-1), y_hat, 'bo')
plt.xlabel("Actual")
plt.ylabel("Prediction")
# Out:
# Text(0, 0.5, 'Prediction')
